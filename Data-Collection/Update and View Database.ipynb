# %%
from functions import *
from Twitter_functions import *

# %%
with open('Authentication/database_uri.txt', 'r', encoding="utf8") as f:
    uri = f.read()

# %%
with open('Authentication/twitter_bearer_token.txt', 'r', encoding="utf8") as f:
    token = f.read()

header = create_Twitter_headers(token)

# %%
# The 3 tables:

# command = '''
#     CREATE TABLE twitter_data (
#     tweet_id VARCHAR NOT NULL,
#     timestamp VARCHAR NOT NULL,
#     tweet VARCHAR
# )
# '''

# command = '''
#     CREATE TABLE reddit_data (
#     post_id VARCHAR NOT NULL,
#     timestamp VARCHAR NOT NULL,
#     post VARCHAR
# )
# '''

# command = '''
#     CREATE TABLE tweets_for_analysis (
#     id VARCHAR NOT NULL,
#     user_id VARCHAR,
#     timestamp VARCHAR NOT NULL,
#     reply_to VARCHAR NOT NULL,
#     comment VARCHAR NOT NULL,
#     social_media VARCHAR,
#     head_id VARCHAR NOT NULL,
#     conversation_id VARCHAR NOT NULL
# )
# '''

# command = '''
#     CREATE TABLE reddit_posts_for_analysis (
#     id VARCHAR NOT NULL,
#     username VARCHAR NOT NULL,
#     timestamp VARCHAR NOT NULL,
#     reply_to VARCHAR NOT NULL,
#     comment VARCHAR NOT NULL,
#     social_media VARCHAR,
#     head_id VARCHAR NOT NULL
# )
# '''

# command = '''
#     CREATE TABLE pheme_dataset_for_analysis (
#     id VARCHAR NOT NULL,
#     timestamp VARCHAR NOT NULL,
#     reply_to VARCHAR NOT NULL,
#     comment VARCHAR NOT NULL,
#     head_id VARCHAR NOT NULL
# )
# '''

# command = '''ALTER TABLE tweets_for_analysis RENAME TO comments_for_analysis'''

# command = '''
#     DELETE FROM comments_for_analysis WHERE conversation_id = '1513829591038627840'
# '''

# command = '''ALTER TABLE comments_for_analysis ADD COLUMN user_id VARCHAR'''

# setUpDB(command, uri)
# print('Done')

# %%
socialMedia = ['Reddit', 'Twitter']

for i in range(len(socialMedia)):
    print(i, socialMedia[i])

socialMediaOption = int(input("Choose social media platform: "))

print(f'\nChosen {socialMedia[socialMediaOption]}\n')

if socialMedia[socialMediaOption] == 'Reddit':
    query = '''
        select * from reddit_posts_for_analysis
    '''
    
    data = getData(query, uri)
    print('Length of dataframe:', len(data))
    print(data['head_id'].unique())
    
elif socialMedia[socialMediaOption] == 'Twitter':
    query = '''
        select * from comments_for_analysis
    '''
    data = getData(query, uri)
    print('Length of dataframe:', len(data))
    print(data['conversation_id'].unique())

data.head()
# Out:
# 0 Reddit
# 1 Twitter
# Choose social media platform: 0
#
# Chosen Reddit
#
# Length of dataframe: 182
# ['rmqevj']
#         id       username            timestamp reply_to  \
# 0  hpr2kav    MapleViolet  2021-12-24 08:55:24   rmqevj
# 1  hra9zzo  HaddockFillet  2022-01-05 08:14:35  hpr2kav
# 2  hpob7bq        kuang89  2021-12-23 20:17:48   rmqevj
# 3  hpprwf1      [deleted]  2021-12-24 03:06:33  hpob7bq
# 4  hprs02i        kuang89  2021-12-24 12:23:36  hpprwf1
#
#                                              comment social_media head_id
# 0  All I know is - anyone trying to pull a fast o...       Reddit  rmqevj
# 1  Why does she think it is OK to lie about such ...       Reddit  rmqevj
# 2  A lie was told in parliament that affects the ...       Reddit  rmqevj
# 3  I would like to add "Public trust in a critica...       Reddit  rmqevj
# 4  Ya missed out on that, police public image als...       Reddit  rmqevj

# %%
for i in data['conversation_id'].unique():
        print(i, ':', getSingleTweetInfo(i, header)['data'][0]['text'], '\n')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'conversation_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17752/2113345123.py in <module>
# ----> 1 for i in data['conversation_id'].unique():
#       2         print(i, ':', getSingleTweetInfo(i, header)['data'][0]['text'], '\n')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'conversation_id'

# %%
query = '''
        select * from pheme_dataset_for_analysis
    '''
getData(query, uri)
# Out:
#                     id                       timestamp  \
# 0   553553974293704704  Tue May 27 18:58:17 +0000 2014
# 1   553553679593521152  Fri May 28 12:14:20 +0000 2010
# 2   553556846746021888  Wed Jun 03 21:35:37 +0000 2009
# 3   553554699350462465  Sun Oct 19 15:53:20 +0000 2014
# 4   553557746751401985  Sun Nov 11 18:14:40 +0000 2012
# 5   553556768723595264  Sat Mar 12 15:42:46 +0000 2011
# 6   553555547900100608  Sun Nov 11 18:14:40 +0000 2012
# 7   553553739144253440  Sun Nov 11 18:14:40 +0000 2012
# 8   553554164639232002  Fri Feb 28 11:29:57 +0000 2014
# 9   553555727697326080  Sun Feb 03 19:08:45 +0000 2013
# 10  553554259971956736  Mon Oct 27 15:47:10 +0000 2014
# 11  553555193720090624  Fri Feb 28 11:29:57 +0000 2014
# 12  553555051390976001  Wed May 19 01:12:52 +0000 2010
# 13  553554083530158080  Sun Oct 19 15:53:20 +0000 2014
# 14  553558123709857792  Fri Feb 28 11:29:57 +0000 2014
# 15  553554457519460353  Mon Oct 27 15:47:10 +0000 2014
# 16  553560780831219712  Wed Jun 03 21:35:37 +0000 2009
# 17  553553396708278272  Fri Feb 28 11:29:57 +0000 2014
# 18  553553708655857664  Wed Nov 10 10:04:32 +0000 2010
# 19  553554772578820097  Mon Jun 28 13:38:19 +0000 2010
# 20  553557043173269505  Fri Feb 28 11:29:57 +0000 2014
# 21  553554411252121600  Wed Jun 03 21:35:37 +0000 2009
# 22  553555111956717568  Mon Oct 27 15:47:10 +0000 2014
# 23  553597738785705985  Sun Feb 22 13:44:56 +0000 2009
# 24  553599330507304961  Thu Mar 24 14:37:11 +0000 2011
# 25  553545520535597056  Sat Aug 25 10:12:25 +0000 2012
# 26  553593372485881856  Sun Feb 22 13:44:56 +0000 2009
# 27  553563400114929664  Wed Mar 13 11:56:19 +0000 2013
# 28  553539534634237952  Fri Jun 10 12:46:20 +0000 2011
# 29  553545201432932352  Sun Feb 26 19:05:19 +0000 2012
# 30  553555330094071808  Wed Jul 01 09:19:20 +0000 2009
# 31  553596787639205888  Thu Mar 24 14:37:11 +0000 2011
# 32  553559505980891136  Thu Nov 21 17:22:58 +0000 2013
# 33  553597806217535488  Sun Feb 22 13:44:56 +0000 2009
# 34  553560882966712321  Tue Nov 30 09:20:05 +0000 2010
# 35  553592489521971200  Thu Mar 24 14:37:11 +0000 2011
# 36  553540187436113921  Mon Oct 22 18:28:05 +0000 2012
# 37  553963921456267265  Thu Mar 24 14:37:11 +0000 2011
# 38  553539063542992896  Wed Jul 31 20:39:53 +0000 2013
# 39  553578351680839680  Mon Nov 23 20:58:24 +0000 2009
# 40  553544505220407296  Thu Feb 23 18:08:11 +0000 2012
# 41  555297666536861696  Fri Dec 19 16:00:21 +0000 2014
# 42  553538852225552385  Sun Aug 07 20:33:19 +0000 2011
# 43  553579976126382081  Sun Feb 22 13:44:56 +0000 2009
# 44  553539311027912704  Wed Aug 13 16:09:26 +0000 2014
# 45  553551111391830018  Mon Feb 20 03:19:38 +0000 2012
# 46  554020988502167552  Tue Aug 06 12:37:55 +0000 2013
# 47  553578069655834624  Mon Nov 23 20:58:24 +0000 2009
# 48  553560102415106049  Fri Nov 01 14:48:36 +0000 2013
# 49  553907222787682304  Sun Feb 22 13:44:56 +0000 2009
# 50  553906805840285696  Sat Jun 27 19:52:43 +0000 2009
# 51  553565643182981120  Sat Sep 03 22:13:45 +0000 2011
# 52  553542266787479553  Mon Oct 25 07:43:14 +0000 2010
# 53  553540596959559680  Sun Feb 22 13:44:56 +0000 2009
# 54  553592628638646273  Thu Mar 24 14:37:11 +0000 2011
# 55  553559092464459776  Sun May 31 10:56:34 +0000 2009
# 56  553582950651277312  Tue Aug 30 09:04:12 +0000 2011
# 57  553596846359470081  Thu Mar 24 14:37:11 +0000 2011
# 58  553554633801879552  Sun May 09 22:58:06 +0000 2010
#
#                   reply_to                                            comment  \
# 0       553553331671408641  @SkyNews don't think they will like the coming...
# 1       553553331671408641  Jeez.. “@SkyNews: Armed police arrest young pe...
# 2       553555193720090624  @genlady9 Israel thanks you for another $100  ...
# 3       553554457519460353  @DevilsAdvocateU oh yes ofcourse but shame the...
# 4       553557043173269505                    @genlady9 @SkyNews no...I'm not
# 5       553553331671408641  WTF “@SkyNews: Armed police arrest young peopl...
# 6       553554164639232002  @genlady9 @SkyNews yet 20% of nobel prizes are...
# 7       553553396708278272                     @genlady9 @SkyNews #FreeIsrael
# 8       553553739144253440  @idfelite @SkyNews who is Israel ? Oh it's a s...
# 9       553553708655857664  @NewsOnTheMin @SkyNews they were possibly call...
# 10      553553974293704704                      @ZirikiZiriki I don't get it?
# 11      553554411252121600  @Baumee @SkyNews hshh bee go away .go to your ...
# 12      553553331671408641  Incredible RT @SkyNews: Armed police arrest yo...
# 13      553553331671408641  @SkyNews what did these youngsters do to be ar...
# 14      553556846746021888                 @Baumee thanks I will do my best.😏
# 15      553554083530158080  @Antonette245 I imagine they were told not to ...
# 16      553558123709857792  @genlady9 I'm tracking your efforts so tweet a...
# 17      553553331671408641  @SkyNews \n#StopKillingInnocentPeople\n#FreePa...
# 18      553553331671408641  PHOTO: Armed police arrest young people on a s...
# 19      553553331671408641  This photo: “@SkyNews: Armed police arrest you...
# 20      553555547900100608       @idfelite @SkyNews lol hahaha are u joking?😂
# 21      553553396708278272  @genlady9 @SkyNews I'm donating $100 to Israel...
# 22      553554699350462465                       @Antonette245 yeah of course
# 23   5.535968463594701e+17  @SirIanBlair @Markwar4 @policecommander @twitt...
# 24   5.535978062175355e+17  @ivorsawbottom @Markwar4 @policecommander @twi...
# 25  5.5354520143293235e+17  @longitude0 Alert, not alarmed is the best advice
# 26   5.535926286386463e+17  @SirIanBlair @Markwar4 @policecommander @twitt...
# 27   5.535325076235469e+17  @policecommander @MikePannett . Bless them all...
# 28   5.535325076235469e+17  @policecommander @GoodNewsCops Amen &amp; God ...
# 29   5.535325076235469e+17  @policecommander Now might be an opportune mom...
# 30   5.535325076235469e+17  @policecommander @misterokoro UNFORTUNATELY TH...
# 31  5.5359337248588186e+17  @ivorsawbottom @Markwar4 @policecommander @twi...
# 32   5.535325076235469e+17  @policecommander Well said. Let us not forget ...
